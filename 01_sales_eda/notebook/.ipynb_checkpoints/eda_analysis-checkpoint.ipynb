# %% [markdown]
# # Sales Data Exploratory Analysis
#
# An exploratory analysis of historical sales data focused on understanding
# sales behavior, profitability patterns, and key business drivers.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('default')

# %% [markdown]
# ## Data Loading and Cleaning

# %%
df = pd.read_csv('../data/superstore.csv')

# Standardize column names to snake_case for cleaner, more Pythonic code
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace('.', '_', regex=False)
)

# Drop the non-informative column with a Chinese label ('record count'),
# which is not needed for this analysis
df = df.drop(columns=['记录数'])

df.head()
# Out:
#           category         city        country customer_id     customer_name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    discount market               order_date        order_id order_priority  \
# 0       0.0     US  2011-01-07 00:00:00.000  CA-2011-130813           High
# 1       0.0     US  2011-01-21 00:00:00.000  CA-2011-148614         Medium
# 2       0.0     US  2011-08-05 00:00:00.000  CA-2011-118962         Medium
# 3       0.0     US  2011-08-05 00:00:00.000  CA-2011-118962         Medium
# 4       0.0     US  2011-09-29 00:00:00.000  CA-2011-146969           High
#
#    ... sales   segment                ship_date       ship_mode shipping_cost  \
# 0  ...    19  Consumer  2011-01-09 00:00:00.000    Second Class          4.37
# 1  ...    19  Consumer  2011-01-26 00:00:00.000  Standard Class          0.94
# 2  ...    21  Consumer  2011-08-09 00:00:00.000  Standard Class          1.81
# 3  ...   111  Consumer  2011-08-09 00:00:00.000  Standard Class          4.59
# 4  ...     6  Consumer  2011-10-03 00:00:00.000  Standard Class          1.32
#
#         state  sub_category  year        market2 weeknum
# 0  California         Paper  2011  North America       2
# 1  California         Paper  2011  North America       4
# 2  California         Paper  2011  North America      32
# 3  California         Paper  2011  North America      32
# 4  California         Paper  2011  North America      40
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (51290, 26)

# %% [markdown]
# The dataset contains 51,290 rows and multiple variables related to orders,customers, products, and sales performance, indicating a transactional-level dataset.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   category        51290 non-null  str
#  1   city            51290 non-null  str
#  2   country         51290 non-null  str
#  3   customer_id     51290 non-null  str
#  4   customer_name   51290 non-null  str
#  5   discount        51290 non-null  float64
#  6   market          51290 non-null  str
#  7   order_date      51290 non-null  str
#  8   order_id        51290 non-null  str
#  9   order_priority  51290 non-null  str
#  10  product_id      51290 non-null  str
#  11  product_name    51290 non-null  str
#  12  profit          51290 non-null  float64
#  13  quantity        51290 non-null  int64
#  14  region          51290 non-null  str
#  15  row_id          51290 non-null  int64
#  16  sales           51290 non-null  int64
#  17  segment         51290 non-null  str
#  18  ship_date       51290 non-null  str
#  19  ship_mode       51290 non-null  str
#  20  shipping_cost   51290 non-null  float64
#  21  state           51290 non-null  str
#  22  sub_category    51290 non-null  str
#  23  year            51290 non-null  int64
#  24  market2         51290 non-null  str
#  25  weeknum         51290 non-null  int64
# dtypes: float64(3), int64(5), str(18)
# memory usage: 10.2 MB

# %% [markdown]
# ## Missing Values Analysis
#
# The dataset does not contain missing values in any of its columns.
# This indicates good data quality and allows the analysis to proceed
# without the need for imputation or row removal.

# %%
df.isnull().sum()
# Out:
# category          0
# city              0
# country           0
# customer_id       0
# customer_name     0
# discount          0
# market            0
# order_date        0
# order_id          0
# order_priority    0
# product_id        0
# product_name      0
# profit            0
# quantity          0
# region            0
# row_id            0
# sales             0
# segment           0
# ship_date         0
# ship_mode         0
# shipping_cost     0
# state             0
# sub_category      0
# year              0
# market2           0
# weeknum           0
# dtype: int64

# %% [markdown]
# ### Date Formatting

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
df['ship_date'] = pd.to_datetime(df['ship_date'])
df['year'] = df['order_date'].dt.year
df['month'] = df['order_date'].dt.month

# %% [markdown]
# Date columns were converted to datetime format to support time-based analysis.
# Numerical and categorical variables present appropriate data types for
# aggregation and grouping. The `month` column was explicitly defined as an
# integer to ensure consistency in temporal analysis.

# %%
df.dtypes
# Out:
# category                     str
# city                         str
# country                      str
# customer_id                  str
# customer_name                str
# discount                 float64
# market                       str
# order_date        datetime64[us]
# order_id                     str
# order_priority               str
# product_id                   str
# product_name                 str
# profit                   float64
# quantity                   int64
# region                       str
# row_id                     int64
# sales                      int64
# segment                      str
# ship_date         datetime64[us]
# ship_mode                    str
# shipping_cost            float64
# state                        str
# sub_category                 str
# year                       int32
# market2                      str
# weeknum                    int64
# month                      int32
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No duplicate records were found in the dataset.

# %% [markdown]
# ### Sales and Profit Distribution
#
# The sales and profit distributions are right-skewed, with mean values
# significantly higher than the median. This indicates that most transactions
# have relatively low sales and profit values, while a small number of high-value
# orders significantly impact the overall averages.
#
# Negative profit values are present, which is expected due to discounts,
# shipping costs, and business strategies.

# %%
df[['sales', 'profit']].describe()
# Out:
#               sales        profit
# count  51290.000000  51290.000000
# mean     246.498440     28.610982
# std      487.567175    174.340972
# min        0.000000  -6599.978000
# 25%       31.000000      0.000000
# 50%       85.000000      9.240000
# 75%      251.000000     36.810000
# max    22638.000000   8399.976000

# %% [markdown]
# #### Are there significant outliers in sales and profit?

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.boxplot(data=df, y='sales', ax=axes[0])
axes[0].set_title('Sales Distribution (Outliers)')

sns.boxplot(data=df, y='profit', ax=axes[1])
axes[1].set_title('Profit Distribution (Outliers)')

plt.tight_layout()
plt.show()

# %% [markdown]
# Both boxplots confirm the right-skewed distributions observed above: sales
# has several high-value outliers pulling the mean upward, while profit shows
# outliers on both ends, including notably negative values. These extreme cases
# are kept in the analysis (rather than removed) since they represent real,
# valid transactions that are important for understanding overall profitability.

# %% [markdown]
# With the data validated and properly formatted, the next step focuses onexploring sales patterns and relationships through visual analysis.

# %% [markdown]
# #### How have total sales evolved over time?

# %%
sales_over_time = df.groupby('year')['sales'].sum()

plt.figure()
sales_over_time.plot()
plt.title('Total Sales Over Time')
plt.xlabel('Year')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# Total sales show a general upward trend over the years covered by the dataset
# (2011–2014), indicating business growth during this period. Some fluctuations
# are observed, which may be related to market conditions or seasonal effects.

# %% [markdown]
# #### Which product categories generate the highest total sales?

# %%
sales_by_category = df.groupby('category')['sales'].sum().reset_index()
sales_by_category = sales_by_category.sort_values(by='sales', ascending=False)

plt.figure()
sns.barplot(
    data=sales_by_category,
    x='category',
    y='sales'
)

plt.title('Total Sales by Product Category')
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.show()

# %%
# Summary table with exact values behind the chart above
sales_by_category
# Out:
#           category    sales
# 2       Technology  4744691
# 0        Furniture  4110884
# 1  Office Supplies  3787330

# %% [markdown]
# The analysis shows that sales are not evenly distributed across productcategories. The Technology category generates the highest total sales,followed by Furniture and Office Supplies. This suggests that technologyproducts play a key role in the company's revenue.

# %% [markdown]
# #### What is the relationship between sales value and profit?

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x='sales',
    y='profit',
    alpha=0.5
)

plt.axhline(0)
plt.title('Profit vs Sales')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# The relationship between sales and profit is generally positive, but higher
# sales do not always translate into higher profit. Several transactions with
# high sales values result in low or even negative profit, indicating the impact
# of discounts, shipping costs, or pricing strategies.

# %% [markdown]
# #### Which category–region combinations drive sales performance?

# %%
pivot_table = df.pivot_table(
    values='sales',
    index='category',
    columns='region',
    aggfunc='sum'
)

plt.figure(figsize=(12, 6))

sns.heatmap(
    pivot_table,
    cmap='Blues',
    annot=True,
    fmt='.0f'
)

plt.title('Sales by Category and Region')
plt.xlabel('Region')
plt.ylabel('Category')

plt.show()

# %% [markdown]
# Sales performance varies across regions and product categories. Some categories
# perform particularly well in specific regions, while others show more balanced
# results. This suggests opportunities for more targeted regional and category-
# focused strategies.

# %% [markdown]
# ## Final Conclusions
#
# This exploratory analysis helped highlight key sales patterns, profitability
# drivers, and regional differences. The results reinforce the importance of
# understanding not only total sales, but also how profit behaves across products
# and regions.
#
# **Business recommendations:**
# - Investigate discount and shipping cost policies for high-sales/low-profit
#   transactions, since higher sales do not consistently translate into higher profit.
# - Prioritize category-region combinations with the strongest sales performance
#   for targeted marketing and inventory planning.
# - Use these findings as a foundation for further analysis, such as predictive
#   modeling of profitability or dashboard development for ongoing monitoring.
